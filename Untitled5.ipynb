# %%
# !pip install pyqlib
# !python -m qlib.install --enable_yahoo
# Out:
# ...
# C:\Users\KIIT\anaconda3\python.exe: No module named qlib.install

# %%
import qlib
from qlib.data import D
from qlib.contrib.model.pytorch_gru import GRU
from qlib.utils import init_instance_by_config
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
